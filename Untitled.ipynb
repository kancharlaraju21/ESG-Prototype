# %%
import pandas as pd

# %%
df=pd.read_csv('gri_data.csv')

# %%
import matplotlib.pyplot as plt
from io import StringIO

# %%
df.plot()
# Out:
# []

# %%
list(df['year'].values)
# Out:
# [2016, 2017, 2018, 2019, 2020, 2021]

# %%
df.columns
# Out:
# Index(['non_renewable_materials_used', 'renewable_materials_used',
#        'recycled_percentage', 'fuel_consumption_with_non_renewable_sources',
#        'fuel_consumption_with_renewable_sources',
#        'surface_water_withdrawal_megaliters',
#        'ground_water_withdrawal_megaliters',
#        'surface_water_withdrawal_with_watre_stress',
#        'ground_water_withdrawal_with_watre_stress', 'year'],
#       dtype='object')

# %%
list(df[['non_renewable_materials_used','surface_water_withdrawal_megaliters','ground_water_withdrawal_megaliters']].values)
# Out:
# array([[22, 54, 90],
#        [47, 41, 69],
#        [10, 71, 63],
#        [21, 28, 22],
#        [42, 61, 59],
#        [36, 27,  7]], dtype=int64)

# %%
import random
a=[]
for i in ['non_renewable_materials_used','surface_water_withdrawal_megaliters','ground_water_withdrawal_megaliters']:
    t=dict()
    t['label']=i
    t['data']=list(df[i].values)
    t['backgroundColor']="rgba({},{},{},0.2)".format(random.randint(0,255),random.randint(0,255),random.randint(0,255))
    a.append(t)
    
print(a)
# Out:
# [{'label': 'non_renewable_materials_used', 'data': [22, 47, 10, 21, 42, 36], 'backgroundColor': 'rgba(90,60,223,0.2)'}, {'label': 'surface_water_withdrawal_megaliters', 'data': [54, 41, 71, 28, 61, 27], 'backgroundColor': 'rgba(74,35,67,0.2)'}, {'label': 'ground_water_withdrawal_megaliters', 'data': [90, 69, 63, 22, 59, 7], 'backgroundColor': 'rgba(59,236,250,0.2)'}]

# %%
import random
a=[]
for i in ['non_renewable_materials_used','surface_water_withdrawal_megaliters','ground_water_withdrawal_megaliters']:
    ip="label: {},backgroundColor: 'rgba({},{},{},0.2)',data: {},".format(i,random.randint(0,255),random.randint(0,255),random.randint(0,255),df[i].values)
    print(ip)
print(a)
# Out:
# label: non_renewable_materials_used,backgroundColor: 'rgba(121,35,68,0.2)',data: [22 47 10 21 42 36],
# label: surface_water_withdrawal_megaliters,backgroundColor: 'rgba(28,125,62,0.2)',data: [54 41 71 28 61 27],
# label: ground_water_withdrawal_megaliters,backgroundColor: 'rgba(86,68,185,0.2)',data: [90 69 63 22 59  7],
# []

# %%
# Out:
# ['non_renewable_materials_used',
#  'renewable_materials_used',
#  'recycled_percentage',
#  'fuel_consumption_with_non_renewable_sources',
#  'fuel_consumption_with_renewable_sources',
#  'surface_water_withdrawal_megaliters',
#  'ground_water_withdrawal_megaliters',
#  'surface_water_withdrawal_with_watre_stress',
#  'ground_water_withdrawal_with_watre_stress']
